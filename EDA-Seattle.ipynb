# %% [markdown]
# # EDA

# %%
# %matplotlib inline
import os
import matplotlib
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('data1/dataset_seattle.csv')

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Cooling:Electricity [kW](Hourly)',
#        'Date/Time', 'Electricity:Facility [kW](Hourly)',
#        'Electricity:Facility [kW](Monthly)', 'Fans:Electricity [kW](Hourly)',
#        'Gas:Facility [kW](Hourly)', 'Gas:Facility [kW](Monthly)',
#        'Heating:Electricity [kW](Hourly)', 'Heating:Gas [kW](Hourly)',
#        'InteriorEquipment:Electricity [kW](Hourly)',
#        'InteriorEquipment:Gas [kW](Hourly)',
#        'InteriorLights:Electricity [kW](Hourly)',
#        'Water Heater:WaterSystems:Gas [kW](Hourly)', 'building_type',
#        'location', 'location_id', 'building_id', 'Date', 'time', 'sunriseTime',
#        'sunsetTime', 'temperatureHigh', 'dewPoint', 'humidity', 'windSpeed',
#        'cloudCover', 'Christmas Day', 'Columbus Day', 'Independence Day',
#        'Labor Day', 'Martin Luther King Day', 'Memorial Day', 'New Years Day',
#        'Presidents Day', 'Thanksgiving', 'Veterans Day', 'Day', 'is_weekend',
#        'is_holiday', 'Holiday_name', 'Friday', 'Monday', 'Saturday', 'Sunday',
#        'Thursday', 'Tuesday', 'Wednesday', 'RefBldgFullServiceRestaurantNew',
#        'RefBldgHospitalNew', 'RefBldgLargeHotelNew', 'RefBldgLargeOfficeNew',
#        'RefBldgMediumOfficeNew', 'RefBldgMidriseApartmentNew',
#        'RefBldgOutPatientNew', 'RefBldgPrimarySchoolNew',
#        'RefBldgQuickServiceRestaurantNew', 'RefBldgSecondarySchoolNew',
#        'RefBldgSmallHotelNew', 'RefBldgSmallOfficeNew',
#        'RefBldgStand-aloneRetailNew', 'RefBldgStripMallNew',
#        'RefBldgSuperMarketNew', 'RefBldgWarehouseNew', 'USA_WA_SEATTLE'],
#       dtype='object')

# %%
dataset.plot(kind='scatter', x='Cooling:Electricity [kW](Hourly)', y='Electricity:Facility [kW](Hourly)', c='Fans:Electricity [kW](Hourly)',figsize=[20,20])

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='hist', alpha=0.5, figsize=(20,10))

# %%
dataset[['Electricity:Facility [kW](Hourly)', 'Fans:Electricity [kW](Hourly)',
       'Gas:Facility [kW](Hourly)', 'Gas:Facility [kW](Monthly)',
       'Heating:Electricity [kW](Hourly)', 'Heating:Gas [kW](Hourly)',
       'InteriorEquipment:Electricity [kW](Hourly)',
       'InteriorEquipment:Gas [kW](Hourly)',
       'InteriorLights:Electricity [kW](Hourly)',
       'Water Heater:WaterSystems:Gas [kW](Hourly)','time', 'sunriseTime',
       'sunsetTime', 'temperatureHigh', 'dewPoint', 'humidity', 'windSpeed']].hist(figsize=(20,20)) # Histogram for all features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a170437b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17078a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a170bde48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a170e9400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a17111978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1713aef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1716c4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17193a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a17193a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a171c4fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a171f7588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1721db00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1724e0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17276630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1729dba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a172cd160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a172f76d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1731ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17350208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17378780>]],
#       dtype=object)

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Electricity:Facility [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Fans:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Gas:Facility [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Heating:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Heating:Gas [kW](Hourly)'].plot(kind='kde')

# %%
dataset['InteriorEquipment:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['temperatureHigh'].plot(kind='kde')

# %%
dataset['windSpeed'].plot(kind='kde')

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="InteriorEquipment:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="InteriorEquipment:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="Cooling:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="InteriorEquipment:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="Fans:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="InteriorLights:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="Gas:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="temperatureHigh", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="is_holiday", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="is_weekend", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
# dataset.plot(kind='scatter', x='Cooling:Electricity [kW](Hourly)', y='Electricity:Facility [kW](Hourly)', c='Fans:Electricity [kW](Hourly)',figsize=[20,20])
dataset.plot(kind="scatter", x="Fans:Electricity [kW](Hourly)", y="Cooling:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
corr_matrix = dataset.corr()
corr_matrix["Cooling:Electricity [kW](Hourly)"].sort_values(ascending=False)
# Out:
# Cooling:Electricity [kW](Hourly)              1.000000
# RefBldgHospitalNew                            0.867169
# Fans:Electricity [kW](Hourly)                 0.850635
# Electricity:Facility [kW](Hourly)             0.848468
# InteriorEquipment:Electricity [kW](Hourly)    0.593184
# Gas:Facility [kW](Hourly)                     0.508780
# InteriorEquipment:Gas [kW](Hourly)            0.488430
# InteriorLights:Electricity [kW](Hourly)       0.470834
# Heating:Gas [kW](Hourly)                      0.462027
# Water Heater:WaterSystems:Gas [kW](Hourly)    0.174651
# RefBldgLargeHotelNew                          0.097134
# temperatureHigh                               0.096428
# dewPoint                                      0.096035
# RefBldgLargeOfficeNew                         0.069110
# Unnamed: 0                                    0.024488
# sunsetTime                                    0.023513
# time                                          0.023446
# Unnamed: 0.1                                  0.023433
# sunriseTime                                   0.023416
# RefBldgSecondarySchoolNew                     0.017694
# is_weekend                                    0.008718
# Labor Day                                     0.008648
# Wednesday                                     0.007676
# Memorial Day                                  0.006850
# Saturday                                      0.006440
# Tuesday                                       0.005919
# Sunday                                        0.004825
# Monday                                        0.003805
# Independence Day                              0.002405
# Christmas Day                                -0.001963
# is_holiday                                   -0.002781
# Columbus Day                                 -0.002984
# Presidents Day                               -0.004239
# New Years Day                                -0.004412
# Thanksgiving                                 -0.004719
# Martin Luther King Day                       -0.005751
# Veterans Day                                 -0.008710
# Thursday                                     -0.009363
# windSpeed                                    -0.015093
# Friday                                       -0.019038
# RefBldgOutPatientNew                         -0.037408
# cloudCover                                   -0.043833
# humidity                                     -0.045942
# Heating:Electricity [kW](Hourly)             -0.055053
# RefBldgSmallHotelNew                         -0.081208
# RefBldgMediumOfficeNew                       -0.086254
# RefBldgPrimarySchoolNew                      -0.088184
# RefBldgMidriseApartmentNew                   -0.092912
# RefBldgStripMallNew                          -0.094447
# RefBldgStand-aloneRetailNew                  -0.094508
# RefBldgFullServiceRestaurantNew              -0.094596
# RefBldgSuperMarketNew                        -0.094712
# RefBldgQuickServiceRestaurantNew             -0.095536
# RefBldgSmallOfficeNew                        -0.095576
# RefBldgWarehouseNew                          -0.095765
# building_id                                  -0.418790
# Electricity:Facility [kW](Monthly)                 NaN
# Gas:Facility [kW](Monthly)                         NaN
# location_id                                        NaN
# USA_WA_SEATTLE                                     NaN
# Name: Cooling:Electricity [kW](Hourly), dtype: float64

# %%
dataset.plot(kind="scatter", x="time", y="Electricity:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()
