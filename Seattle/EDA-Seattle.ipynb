# %% [markdown]
# # EDA

# %%
# %matplotlib inline
import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import matplotlib
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from pandas.plotting import scatter_matrix
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
from EnergyScience.utilities import epoch_to_date

# %%
dataset = pd.read_csv('../data1/dataset_seattle.csv')

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Cooling:Electricity [kW](Hourly)',
#        'Date/Time', 'Electricity:Facility [kW](Hourly)',
#        'Fans:Electricity [kW](Hourly)', 'Gas:Facility [kW](Hourly)',
#        'Heating:Electricity [kW](Hourly)', 'Heating:Gas [kW](Hourly)',
#        'InteriorEquipment:Electricity [kW](Hourly)',
#        'InteriorEquipment:Gas [kW](Hourly)',
#        'InteriorLights:Electricity [kW](Hourly)',
#        'Water Heater:WaterSystems:Gas [kW](Hourly)', 'building_type',
#        'location', 'location_id', 'building_id', 'Date', 'time', 'sunriseTime',
#        'sunsetTime', 'temperatureHigh', 'dewPoint', 'humidity', 'windSpeed',
#        'cloudCover', 'Electricity:Facility [kW](Hourly)_lag',
#        'Electricity:Facility [kW](Hourly)_future',
#        'Electricity:Facility_delta_current_lag', 'Christmas Day',
#        'Columbus Day', 'Independence Day', 'Labor Day',
#        'Martin Luther King Day', 'Memorial Day', 'New Years Day',
#        'Presidents Day', 'Thanksgiving', 'Veterans Day', 'Day', 'is_weekend',
#        'is_holiday', 'Holiday_name', 'day_of_week', 'Friday', 'Monday',
#        'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday',
#        'RefBldgFullServiceRestaurantNew', 'RefBldgHospitalNew',
#        'RefBldgLargeHotelNew', 'RefBldgLargeOfficeNew',
#        'RefBldgMediumOfficeNew', 'RefBldgMidriseApartmentNew',
#        'RefBldgOutPatientNew', 'RefBldgPrimarySchoolNew',
#        'RefBldgQuickServiceRestaurantNew', 'RefBldgSecondarySchoolNew',
#        'RefBldgSmallHotelNew', 'RefBldgSmallOfficeNew',
#        'RefBldgStand-aloneRetailNew', 'RefBldgStripMallNew',
#        'RefBldgSuperMarketNew', 'RefBldgWarehouseNew', 'USA_WA_SEATTLE',
#        'month'],
#       dtype='object')

# %%
dataset.plot(kind='scatter', x='Cooling:Electricity [kW](Hourly)', y='Electricity:Facility [kW](Hourly)', c='Fans:Electricity [kW](Hourly)',figsize=[20,20])

# %%
heatmap1_data = pd.pivot_table(dataset, values='Gas:Facility [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='Cooling:Electricity [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='Heating:Electricity [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='Heating:Gas [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='Electricity:Facility [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='InteriorEquipment:Electricity [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='temperatureHigh', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='InteriorLights:Electricity [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='hist', alpha=0.5, figsize=(20,10))

# %%
dataset[['Electricity:Facility [kW](Hourly)', 'Fans:Electricity [kW](Hourly)',
       'Gas:Facility [kW](Hourly)',
       'Heating:Electricity [kW](Hourly)', 'Heating:Gas [kW](Hourly)',
       'InteriorEquipment:Electricity [kW](Hourly)',
       'InteriorEquipment:Gas [kW](Hourly)',
       'InteriorLights:Electricity [kW](Hourly)',
       'Water Heater:WaterSystems:Gas [kW](Hourly)','time', 'sunriseTime',
       'sunsetTime', 'temperatureHigh', 'dewPoint', 'humidity', 'windSpeed']].hist(figsize=(20,20)) # Histogram for all features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a267dbfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a279e4208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27a09710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27a30c88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27a61240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27a8a7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27ab3d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27ae5320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27ae5358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27b25c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27b57240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27b7c7b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a27ba4d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27bd72e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27c00860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27c27dd8>]],
#       dtype=object)

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Electricity:Facility [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Fans:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Gas:Facility [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Heating:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Heating:Gas [kW](Hourly)'].plot(kind='kde')

# %%
dataset['InteriorEquipment:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['temperatureHigh'].plot(kind='kde')

# %%
dataset['windSpeed'].plot(kind='kde')

# %%
dataset.plot(kind="scatter", x="temperatureHigh", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
plt.show()

# %%
dataset.plot(kind="scatter", x="InteriorEquipment:Electricity [kW](Hourly)", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Water Heater:WaterSystems:Gas [kW](Hourly)", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="InteriorLights:Electricity [kW](Hourly)", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="RefBldgLargeHotelNew", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="RefBldgMediumOfficeNew", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="Gas:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="temperatureHigh", y="Electricity:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="is_holiday", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="RefBldgHospitalNew", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
# dataset.plot(kind='scatter', x='Cooling:Electricity [kW](Hourly)', y='Electricity:Facility [kW](Hourly)', c='Fans:Electricity [kW](Hourly)',figsize=[20,20])
dataset.plot(kind="scatter", x="Fans:Electricity [kW](Hourly)", y="Cooling:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
corr_matrix = dataset.corr()
corr_matrix["Electricity:Facility [kW](Hourly)_future"].sort_values(ascending=False)
# Out:
# Electricity:Facility [kW](Hourly)_future      1.000000
# RefBldgLargeHotelNew                          0.724359
# Water Heater:WaterSystems:Gas [kW](Hourly)    0.650177
# RefBldgMediumOfficeNew                        0.402842
# InteriorEquipment:Gas [kW](Hourly)            0.276767
# Electricity:Facility [kW](Hourly)_lag         0.244781
# Heating:Electricity [kW](Hourly)              0.161458
# Gas:Facility [kW](Hourly)                     0.144028
# InteriorEquipment:Electricity [kW](Hourly)    0.098185
# RefBldgSmallHotelNew                          0.080537
# RefBldgLargeOfficeNew                         0.072545
# InteriorLights:Electricity [kW](Hourly)       0.065154
# Electricity:Facility [kW](Hourly)             0.059379
# Fans:Electricity [kW](Hourly)                 0.038090
# is_weekend                                    0.035386
# temperatureHigh                               0.028246
# Monday                                        0.026009
# Sunday                                        0.024994
# Tuesday                                       0.024958
# dewPoint                                      0.024561
# Cooling:Electricity [kW](Hourly)              0.021536
# Saturday                                      0.020771
# Wednesday                                     0.015959
# Unnamed: 0                                    0.006652
# Labor Day                                     0.006469
# Unnamed: 0.1                                  0.005838
# sunsetTime                                    0.005813
# time                                          0.005795
# sunriseTime                                   0.005787
# month                                         0.005618
#                                                 ...
# Presidents Day                                0.001898
# Martin Luther King Day                        0.001782
# RefBldgWarehouseNew                          -0.001417
# is_holiday                                   -0.005093
# Thanksgiving                                 -0.006859
# Independence Day                             -0.008217
# windSpeed                                    -0.008907
# Christmas Day                                -0.009307
# New Years Day                                -0.009667
# Veterans Day                                 -0.010940
# cloudCover                                   -0.015695
# humidity                                     -0.018517
# RefBldgPrimarySchoolNew                      -0.033318
# Thursday                                     -0.050571
# Friday                                       -0.061084
# RefBldgQuickServiceRestaurantNew             -0.079903
# RefBldgMidriseApartmentNew                   -0.089572
# Heating:Gas [kW](Hourly)                     -0.093687
# RefBldgSmallOfficeNew                        -0.106229
# RefBldgHospitalNew                           -0.130730
# RefBldgStripMallNew                          -0.131880
# RefBldgSuperMarketNew                        -0.133945
# Electricity:Facility_delta_current_lag       -0.135143
# RefBldgFullServiceRestaurantNew              -0.136645
# RefBldgOutPatientNew                         -0.139383
# RefBldgSecondarySchoolNew                    -0.142387
# RefBldgStand-aloneRetailNew                  -0.155052
# building_id                                  -0.321809
# location_id                                        NaN
# USA_WA_SEATTLE                                     NaN
# Name: Electricity:Facility [kW](Hourly)_future, Length: 62, dtype: float64

# %%
dataset.plot(kind="scatter", x="time", y="Electricity:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Cooling:Electricity [kW](Hourly)',
#        'Date/Time', 'Electricity:Facility [kW](Hourly)',
#        'Fans:Electricity [kW](Hourly)', 'Gas:Facility [kW](Hourly)',
#        'Heating:Electricity [kW](Hourly)', 'Heating:Gas [kW](Hourly)',
#        'InteriorEquipment:Electricity [kW](Hourly)',
#        'InteriorEquipment:Gas [kW](Hourly)',
#        'InteriorLights:Electricity [kW](Hourly)',
#        'Water Heater:WaterSystems:Gas [kW](Hourly)', 'building_type',
#        'location', 'location_id', 'building_id', 'Date', 'time', 'sunriseTime',
#        'sunsetTime', 'temperatureHigh', 'dewPoint', 'humidity', 'windSpeed',
#        'cloudCover', 'Electricity:Facility [kW](Hourly)_lag',
#        'Electricity:Facility [kW](Hourly)_future',
#        'Electricity:Facility_delta_current_lag', 'Christmas Day',
#        'Columbus Day', 'Independence Day', 'Labor Day',
#        'Martin Luther King Day', 'Memorial Day', 'New Years Day',
#        'Presidents Day', 'Thanksgiving', 'Veterans Day', 'Day', 'is_weekend',
#        'is_holiday', 'Holiday_name', 'day_of_week', 'Friday', 'Monday',
#        'Saturday', 'Sunday', 'Thursday', 'Tuesday', 'Wednesday',
#        'RefBldgFullServiceRestaurantNew', 'RefBldgHospitalNew',
#        'RefBldgLargeHotelNew', 'RefBldgLargeOfficeNew',
#        'RefBldgMediumOfficeNew', 'RefBldgMidriseApartmentNew',
#        'RefBldgOutPatientNew', 'RefBldgPrimarySchoolNew',
#        'RefBldgQuickServiceRestaurantNew', 'RefBldgSecondarySchoolNew',
#        'RefBldgSmallHotelNew', 'RefBldgSmallOfficeNew',
#        'RefBldgStand-aloneRetailNew', 'RefBldgStripMallNew',
#        'RefBldgSuperMarketNew', 'RefBldgWarehouseNew', 'USA_WA_SEATTLE',
#        'month', 'date'],
#       dtype='object')

# %%
dataset['date'] = pd.to_datetime(dataset['Date'], format="%m/%d")

# %%
dataset1 = dataset.groupby('date')['Electricity:Facility [kW](Hourly)'].sum().reset_index()
dataset1 = dataset.set_index('date')
dataset1.index
# Out:
# DatetimeIndex(['1900-01-01', '1900-01-01', '1900-01-01', '1900-01-01',
#                '1900-01-01', '1900-01-01', '1900-01-01', '1900-01-01',
#                '1900-01-01', '1900-01-01',
#                ...
#                '1900-12-31', '1900-12-31', '1900-12-31', '1900-12-31',
#                '1900-12-31', '1900-12-31', '1900-12-31', '1900-12-31',
#                '1900-12-31', '1900-12-31'],
#               dtype='datetime64[ns]', name='date', length=140112, freq=None)

# %%
y = dataset1['Electricity:Facility [kW](Hourly)'].resample('MS').mean()

# %%
y.plot(figsize=(15, 6))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import matplotlib.ticker as plticker

matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

dataset = dataset.set_index('date')
furniture.index

x = dataset['Date']
y = dataset['Electricity:Facility [kW](Hourly)']
fig, ax = plt.subplots()
plt.figure(figsize=(32,5), dpi=1000)
ax.plot(x,y)
loc = plticker.MultipleLocator(base=50.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)
plt.show()

# %%
type(dataset['Date/Time'][0])
# Out:
# str

# %%
"""
fig = plt.figure(figsize=(10,6))

#ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.05, 0.65, 0.5, 0.3])

# ax1.set_title('AAPL vs IBM(inset)')

#ax1.plot(stock_data['Date'],
#         stock_data['AAPL'],
#         color='green')

dataset['Date1'] = pd.to_datetime(dataset['Date/Time'])

ax2.plot(dataset['Date1'],
         dataset['Electricity:Facility [kW](Hourly)'], 
         color='blue')
plt.show()
"""
# Out:
# "\nfig = plt.figure(figsize=(10,6))\n\n#ax1 = fig.add_axes([0, 0, 1, 1])\nax2 = fig.add_axes([0.05, 0.65, 0.5, 0.3])\n\n# ax1.set_title('AAPL vs IBM(inset)')\n\n#ax1.plot(stock_data['Date'],\n#         stock_data['AAPL'],\n#         color='green')\n\ndataset['Date1'] = pd.to_datetime(dataset['Date/Time'])\n\nax2.plot(dataset['Date1'],\n         dataset['Electricity:Facility [kW](Hourly)'], \n         color='blue')\nplt.show()\n"

# %%
from pandas.plotting import autocorrelation_plot

# Draw Plot
plt.rcParams.update({'figure.figsize':(9,5), 'figure.dpi':120})
autocorrelation_plot(dataset['Electricity:Facility [kW](Hourly)'])

# %%
df_orig = dataset
df_orig['value'] = dataset['Electricity:Facility [kW](Hourly)']
df_orig.value
# Out:
# 0          85.494324
# 1          84.794544
# 2          84.201696
# 3          83.726241
# 4          89.848974
# 5          89.201522
# 6         126.340442
# 7         138.090475
# 8         159.347215
# 9         134.335479
# 10        168.717441
# 11        199.197292
# 12        207.764355
# 13        205.689266
# 14        201.950546
# 15        198.529917
# 16        208.807236
# 17        183.425973
# 18        188.096366
# 19        169.403265
# 20        160.138010
# 21        144.467298
# 22         88.542035
# 23        122.580139
# 24         14.657581
# 25         14.657581
# 26         14.657581
# 27         14.657581
# 28         14.657581
# 29         14.657581
#              ...
# 140082    340.739211
# 140083    357.137459
# 140084    385.567413
# 140085    358.499056
# 140086    303.971552
# 140087    216.007235
# 140088    784.094984
# 140089    783.522764
# 140090    784.128581
# 140091    783.810373
# 140092    791.125894
# 140093    790.007485
# 140094    861.874456
# 140095    868.339073
# 140096    933.351558
# 140097    927.197928
# 140098    936.497708
# 140099    939.100562
# 140100    940.740954
# 140101    935.674935
# 140102    936.421687
# 140103    935.623712
# 140104    918.629002
# 140105    871.562282
# 140106    821.265070
# 140107    790.275547
# 140108    741.220532
# 140109    735.739831
# 140110    726.895174
# 140111    720.198784
# Name: value, Length: 140112, dtype: float64

# %%
from statsmodels.nonparametric.smoothers_lowess import lowess
plt.rcParams.update({'xtick.bottom' : False, 'axes.titlepad':5})

# Import
df_orig = dataset
df_orig['value'] = dataset['Electricity:Facility [kW](Hourly)']
df_orig.set_index(df_orig['Date'])

# 1. Moving Average
df_ma = df_orig.value.rolling(3, center=True).mean()

# 2. Loess Smoothing (5% and 15%)
df_loess_5 = pd.DataFrame(lowess(df_orig.value, np.arange(len(df_orig.value)), frac=0.05)[:, 1], index=df_orig.index, columns=['value'])
df_loess_15 = pd.DataFrame(lowess(df_orig.value, np.arange(len(df_orig.value)), frac=0.15)[:, 1], index=df_orig.index, columns=['value'])

# Plot
fig, axes = plt.subplots(4,1, figsize=(7, 7), sharex=True, dpi=120)
df_orig['value'].plot(ax=axes[0], color='k', title='Original Series')
df_loess_5['value'].plot(ax=axes[1], title='Loess Smoothed 5%')
df_loess_15['value'].plot(ax=axes[2], title='Loess Smoothed 15%')
df_ma.plot(ax=axes[3], title='Moving Average (3)')
fig.suptitle('How to Smoothen a Time Series', y=0.95, fontsize=14)
plt.show()
