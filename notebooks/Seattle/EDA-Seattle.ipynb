# %% [markdown]
# # EDA

# %%
# %matplotlib inline
import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
import matplotlib
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from pandas.plotting import scatter_matrix
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
from src.utilities import epoch_to_date

# %%
dataset = pd.read_csv('../../data/data1/processed/dataset_seattle.csv')

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Cooling:Electricity [kW](Hourly)', 'Date/Time',
#        'Electricity:Facility [kW](Hourly)', 'Fans:Electricity [kW](Hourly)',
#        'Gas:Facility [kW](Hourly)', 'Heating:Electricity [kW](Hourly)',
#        'Heating:Gas [kW](Hourly)',
#        'InteriorEquipment:Electricity [kW](Hourly)',
#        'InteriorEquipment:Gas [kW](Hourly)',
#        'InteriorLights:Electricity [kW](Hourly)',
#        'Water Heater:WaterSystems:Gas [kW](Hourly)', 'building_type',
#        'location', 'location_id', 'building_id', 'Date', 'Holiday',
#        'Holiday_code', 'time', 'sunriseTime', 'sunsetTime', 'temperatureHigh',
#        'dewPoint', 'humidity', 'windSpeed', 'cloudCover',
#        'Electricity:Facility [kW](Hourly)_lag',
#        'Electricity:Facility [kW](Hourly)_future',
#        'Electricity:Facility_delta_current_lag'],
#       dtype='object')

# %%
dataset.plot(kind='scatter', x='Cooling:Electricity [kW](Hourly)', y='Electricity:Facility [kW](Hourly)', c='Fans:Electricity [kW](Hourly)',figsize=[20,20])

# %%
heatmap1_data = pd.pivot_table(dataset, values='Gas:Facility [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-aae589b49f87> in <module>
#       1 heatmap1_data = pd.pivot_table(dataset, values='Gas:Facility [kW](Hourly)',
#       2                      index=['month'],
# ----> 3                      columns='day_of_week')
#       4 plt.figure(figsize=(20, 8))
#       5 sns.heatmap(heatmap1_data, cmap="Reds")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      84     # group by the cartesian product of the grouper
#      85     # if we have a categorical
# ---> 86     grouped = data.groupby(keys, observed=False)
#      87     agged = grouped.agg(aggfunc)
#      88     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'month'

# %%
heatmap1_data = pd.pivot_table(dataset, values='Cooling:Electricity [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='Heating:Electricity [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='Heating:Gas [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='Electricity:Facility [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='InteriorEquipment:Electricity [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='temperatureHigh', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
heatmap1_data = pd.pivot_table(dataset, values='InteriorLights:Electricity [kW](Hourly)', 
                     index=['month'], 
                     columns='day_of_week')
plt.figure(figsize=(20, 8))
sns.heatmap(heatmap1_data, cmap="Reds")

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='hist', alpha=0.5, figsize=(20,10))

# %%
dataset[['Electricity:Facility [kW](Hourly)', 'Fans:Electricity [kW](Hourly)',
       'Gas:Facility [kW](Hourly)',
       'Heating:Electricity [kW](Hourly)', 'Heating:Gas [kW](Hourly)',
       'InteriorEquipment:Electricity [kW](Hourly)',
       'InteriorEquipment:Gas [kW](Hourly)',
       'InteriorLights:Electricity [kW](Hourly)',
       'Water Heater:WaterSystems:Gas [kW](Hourly)','time', 'sunriseTime',
       'sunsetTime', 'temperatureHigh', 'dewPoint', 'humidity', 'windSpeed']].hist(figsize=(20,20)) # Histogram for all features

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Electricity:Facility [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Fans:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Gas:Facility [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Heating:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Heating:Gas [kW](Hourly)'].plot(kind='kde')

# %%
dataset['InteriorEquipment:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['temperatureHigh'].plot(kind='kde')

# %%
dataset['windSpeed'].plot(kind='kde')

# %%
dataset.plot(kind="scatter", x="temperatureHigh", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
plt.show()

# %%
dataset.plot(kind="scatter", x="InteriorEquipment:Electricity [kW](Hourly)", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Water Heater:WaterSystems:Gas [kW](Hourly)", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="InteriorLights:Electricity [kW](Hourly)", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="RefBldgLargeHotelNew", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="RefBldgMediumOfficeNew", y="Electricity:Facility [kW](Hourly)_future", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="Gas:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="temperatureHigh", y="Electricity:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="is_holiday", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="RefBldgHospitalNew", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
# dataset.plot(kind='scatter', x='Cooling:Electricity [kW](Hourly)', y='Electricity:Facility [kW](Hourly)', c='Fans:Electricity [kW](Hourly)',figsize=[20,20])
dataset.plot(kind="scatter", x="Fans:Electricity [kW](Hourly)", y="Cooling:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
corr_matrix = dataset.corr()
corr_matrix["Electricity:Facility [kW](Hourly)_future"].sort_values(ascending=False)

# %%
dataset.plot(kind="scatter", x="time", y="Electricity:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.columns

# %%
dataset['date'] = pd.to_datetime(dataset['Date'], format="%m/%d")

# %%
dataset1 = dataset.groupby('date')['Electricity:Facility [kW](Hourly)'].sum().reset_index()
dataset1 = dataset.set_index('date')
dataset1.index

# %%
y = dataset1['Electricity:Facility [kW](Hourly)'].resample('MS').mean()

# %%
y.plot(figsize=(15, 6))
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import matplotlib.ticker as plticker

matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

dataset = dataset.set_index('date')
furniture.index

x = dataset['Date']
y = dataset['Electricity:Facility [kW](Hourly)']
fig, ax = plt.subplots()
plt.figure(figsize=(32,5), dpi=1000)
ax.plot(x,y)
loc = plticker.MultipleLocator(base=50.0) # this locator puts ticks at regular intervals
ax.xaxis.set_major_locator(loc)
plt.show()

# %%
type(dataset['Date/Time'][0])

# %%
"""
fig = plt.figure(figsize=(10,6))

#ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.05, 0.65, 0.5, 0.3])

# ax1.set_title('AAPL vs IBM(inset)')

#ax1.plot(stock_data['Date'],
#         stock_data['AAPL'],
#         color='green')

dataset['Date1'] = pd.to_datetime(dataset['Date/Time'])

ax2.plot(dataset['Date1'],
         dataset['Electricity:Facility [kW](Hourly)'], 
         color='blue')
plt.show()
"""

# %%
from pandas.plotting import autocorrelation_plot

# Draw Plot
plt.rcParams.update({'figure.figsize':(9,5), 'figure.dpi':120})
autocorrelation_plot(dataset['Electricity:Facility [kW](Hourly)'])

# %%
df_orig = dataset
df_orig['value'] = dataset['Electricity:Facility [kW](Hourly)']
df_orig.value

# %%
from statsmodels.nonparametric.smoothers_lowess import lowess
plt.rcParams.update({'xtick.bottom' : False, 'axes.titlepad':5})

# Import
df_orig = dataset
df_orig['value'] = dataset['Electricity:Facility [kW](Hourly)']
df_orig.set_index(df_orig['Date'])

# 1. Moving Average
df_ma = df_orig.value.rolling(3, center=True).mean()

# 2. Loess Smoothing (5% and 15%)
df_loess_5 = pd.DataFrame(lowess(df_orig.value, np.arange(len(df_orig.value)), frac=0.05)[:, 1], index=df_orig.index, columns=['value'])
df_loess_15 = pd.DataFrame(lowess(df_orig.value, np.arange(len(df_orig.value)), frac=0.15)[:, 1], index=df_orig.index, columns=['value'])

# Plot
fig, axes = plt.subplots(4,1, figsize=(7, 7), sharex=True, dpi=120)
df_orig['value'].plot(ax=axes[0], color='k', title='Original Series')
df_loess_5['value'].plot(ax=axes[1], title='Loess Smoothed 5%')
df_loess_15['value'].plot(ax=axes[2], title='Loess Smoothed 15%')
df_ma.plot(ax=axes[3], title='Moving Average (3)')
fig.suptitle('How to Smoothen a Time Series', y=0.95, fontsize=14)
plt.show()
