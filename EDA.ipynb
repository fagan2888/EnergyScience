# %% [markdown]
# # EDA

# %%
# %matplotlib inline
import os
import matplotlib
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('data1/dataset.csv')

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Cooling:Electricity [kW](Hourly)',
#        'Date/Time', 'Electricity:Facility [kW](Hourly)',
#        'Electricity:Facility [kW](Monthly)', 'Fans:Electricity [kW](Hourly)',
#        'Gas:Facility [kW](Hourly)', 'Gas:Facility [kW](Monthly)',
#        'Heating:Electricity [kW](Hourly)', 'Heating:Gas [kW](Hourly)',
#        'InteriorEquipment:Electricity [kW](Hourly)',
#        'InteriorEquipment:Gas [kW](Hourly)',
#        'InteriorLights:Electricity [kW](Hourly)',
#        'Water Heater:WaterSystems:Gas [kW](Hourly)', 'building_type',
#        'location', 'location_id', 'building_id', 'Date', 'time', 'sunriseTime',
#        'sunsetTime', 'temperatureHigh', 'dewPoint', 'humidity', 'windSpeed',
#        'cloudCover', 'Christmas Day', 'Columbus Day', 'Independence Day',
#        'Labor Day', 'Martin Luther King Day', 'Memorial Day', 'New Years Day',
#        'Presidents Day', 'Thanksgiving', 'Veterans Day', 'Day', 'is_weekend',
#        'is_holiday', 'Holiday_name', 'Friday', 'Monday', 'Saturday', 'Sunday',
#        'Thursday', 'Tuesday', 'Wednesday', 'RefBldgFullServiceRestaurantNew',
#        'RefBldgHospitalNew', 'RefBldgLargeHotelNew', 'RefBldgLargeOfficeNew',
#        'RefBldgMediumOfficeNew', 'RefBldgMidriseApartmentNew',
#        'RefBldgOutPatientNew', 'RefBldgPrimarySchoolNew',
#        'RefBldgQuickServiceRestaurantNew', 'RefBldgSecondarySchoolNew',
#        'RefBldgSmallHotelNew', 'RefBldgSmallOfficeNew',
#        'RefBldgStand-aloneRetailNew', 'RefBldgStripMallNew',
#        'RefBldgSuperMarketNew', 'RefBldgWarehouseNew', 'USA_AK_FAIRBANKS',
#        'USA_AZ_PHOENIX', 'USA_CA_LOS_ANGELES', 'USA_CA_SAN_FRANCISCO',
#        'USA_CO_BOULDER', 'USA_GA_ATLANTA', 'USA_IL_CHICAGO-OHARE',
#        'USA_MD_BALTIMORE', 'USA_MN_MINNEAPOLIS', 'USA_NV_LAS_VEGAS',
#        'USA_TX_HOUSTON', 'USA_WA_SEATTLE'],
#       dtype='object')

# %%
dataset.plot(kind='scatter', x='Cooling:Electricity [kW](Hourly)', y='Electricity:Facility [kW](Hourly)', c='Fans:Electricity [kW](Hourly)',figsize=[20,20])

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='hist', alpha=0.5, figsize=(20,10))

# %%
dataset[['Electricity:Facility [kW](Hourly)', 'Fans:Electricity [kW](Hourly)',
       'Gas:Facility [kW](Hourly)', 'Gas:Facility [kW](Monthly)',
       'Heating:Electricity [kW](Hourly)', 'Heating:Gas [kW](Hourly)',
       'InteriorEquipment:Electricity [kW](Hourly)',
       'InteriorEquipment:Gas [kW](Hourly)',
       'InteriorLights:Electricity [kW](Hourly)',
       'Water Heater:WaterSystems:Gas [kW](Hourly)','time', 'sunriseTime',
       'sunsetTime', 'temperatureHigh', 'dewPoint', 'humidity', 'windSpeed']].hist(figsize=(20,20)) # Histogram for all features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a338e25f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a36079eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a360ad160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a360d3438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a360fa9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a36123f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a361544e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3617ba90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a3617bac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a361d5588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a361feb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a362300b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a36259630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3627fba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a362af160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a362d76d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a362fec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3632f208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a3635a780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a36381cf8>]],
#       dtype=object)

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Cooling:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Electricity:Facility [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Fans:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Gas:Facility [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Heating:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['Heating:Gas [kW](Hourly)'].plot(kind='kde')

# %%
dataset['InteriorEquipment:Electricity [kW](Hourly)'].plot(kind='kde')

# %%
dataset['temperatureHigh'].plot(kind='kde')

# %%
dataset['windSpeed'].plot(kind='kde')

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="InteriorEquipment:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="InteriorEquipment:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="Cooling:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="InteriorEquipment:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="Fans:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="InteriorLights:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="Gas:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="temperatureHigh", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="is_holiday", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
dataset.plot(kind="scatter", x="Electricity:Facility [kW](Hourly)", y="is_weekend", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
# dataset.plot(kind='scatter', x='Cooling:Electricity [kW](Hourly)', y='Electricity:Facility [kW](Hourly)', c='Fans:Electricity [kW](Hourly)',figsize=[20,20])
dataset.plot(kind="scatter", x="Fans:Electricity [kW](Hourly)", y="Cooling:Electricity [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()

# %%
corr_matrix = dataset.corr()
corr_matrix["Cooling:Electricity [kW](Hourly)"].sort_values(ascending=False)
# Out:
# Cooling:Electricity [kW](Hourly)              1.000000
# Electricity:Facility [kW](Hourly)             0.876445
# Fans:Electricity [kW](Hourly)                 0.810266
# RefBldgHospitalNew                            0.708894
# InteriorEquipment:Electricity [kW](Hourly)    0.608354
# InteriorLights:Electricity [kW](Hourly)       0.541319
# InteriorEquipment:Gas [kW](Hourly)            0.409674
# Gas:Facility [kW](Hourly)                     0.331070
# Heating:Gas [kW](Hourly)                      0.285689
# RefBldgSecondarySchoolNew                     0.174716
# temperatureHigh                               0.167751
# RefBldgLargeOfficeNew                         0.159795
# dewPoint                                      0.140172
# Water Heater:WaterSystems:Gas [kW](Hourly)    0.128953
# RefBldgLargeHotelNew                          0.072023
# USA_TX_HOUSTON                                0.070282
# USA_AZ_PHOENIX                                0.062997
# USA_GA_ATLANTA                                0.047898
# Unnamed: 0.1                                  0.028948
# Unnamed: 0                                    0.028948
# sunsetTime                                    0.028839
# time                                          0.028773
# sunriseTime                                   0.028741
# USA_MD_BALTIMORE                              0.023339
# USA_NV_LAS_VEGAS                              0.015075
# is_weekend                                    0.013713
# Labor Day                                     0.010387
# Sunday                                        0.009718
# Wednesday                                     0.009713
# Monday                                        0.009695
#                                                 ...
# Christmas Day                                -0.009863
# Martin Luther King Day                       -0.010016
# USA_IL_CHICAGO-OHARE                         -0.013894
# location_id                                  -0.017126
# Thursday                                     -0.019266
# windSpeed                                    -0.023507
# USA_CA_SAN_FRANCISCO                         -0.023909
# Friday                                       -0.027001
# USA_MN_MINNEAPOLIS                           -0.032929
# humidity                                     -0.033847
# RefBldgOutPatientNew                         -0.039852
# USA_CO_BOULDER                               -0.040398
# USA_WA_SEATTLE                               -0.040976
# Heating:Electricity [kW](Hourly)             -0.054205
# cloudCover                                   -0.057365
# USA_AK_FAIRBANKS                             -0.071064
# RefBldgPrimarySchoolNew                      -0.082137
# RefBldgSmallHotelNew                         -0.085375
# RefBldgMediumOfficeNew                       -0.086358
# RefBldgMidriseApartmentNew                   -0.099615
# RefBldgSuperMarketNew                        -0.099826
# RefBldgStand-aloneRetailNew                  -0.100221
# RefBldgStripMallNew                          -0.101273
# RefBldgFullServiceRestaurantNew              -0.102284
# RefBldgQuickServiceRestaurantNew             -0.105747
# RefBldgWarehouseNew                          -0.105957
# RefBldgSmallOfficeNew                        -0.106781
# building_id                                  -0.374571
# Electricity:Facility [kW](Monthly)                 NaN
# Gas:Facility [kW](Monthly)                         NaN
# Name: Cooling:Electricity [kW](Hourly), Length: 71, dtype: float64

# %%
dataset.plot(kind="scatter", x="time", y="Electricity:Facility [kW](Hourly)", alpha=0.5)
#plt.savefig('scatter.png')
#scatter_matrix(dataset_numeric, alpha=0.2, figsize=(25,25), diagonal='kde')
plt.show()
